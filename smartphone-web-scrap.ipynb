# %%
with open('smartprix.html','r', encoding='utf-8') as f:
    html = f.read()

# %%
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd

# %%
soup = BeautifulSoup(html, 'lxml')

# %%
containers = soup.find_all('div', {'class':'sm-product has-tag has-features has-actions'})

# %%
names = []
prices = []
ratings = []
sim = []
processor = []
ram = []
battery = []
display = []
camera = []
card = []
os = []

for i in soup.find_all('div',{'class':'sm-product has-tag has-features has-actions'}):
    try:
        names.append(i.find('h2').text)
    except:
        names.append(np.nan)
    try:
        prices.append(i.find('span',{'class':'price'}).text)
    except:
        price.append(np.nan)
    try:
        ratings.append(i.find('div',{'class':'score rank-2-bg'}).find('b').text)
    except:
        ratings.append(np.nan)
        
    x = i.find('ul',{'class':'sm-feat specs'}).find_all('li')
    try:
        sim.append(x[0].text)
    except:
        sim.append(np.nan)
    try:
        processor.append(x[1].text)
    except:
        processor.append(np.nan)
    try:    
        ram.append(x[2].text)
    except:
        ram.append(np.nan)
    try:
        battery.append(x[3].text)
    except:
        battery.append(np.nan)
    try:
        display.append(x[4].text)
    except:
        display.append(np.nan)
    try:
        camera.append(x[5].text)
    except:
        camera.append(np.nan)
    try:
        card.append(x[6].text)
    except:
        card.append(np.nan)
    try:
        os.append(x[7].text)
    except:
        os.append(np.nan)

# %%
len(name)
# Out:
# 20

# %%
df = pd.DataFrame({
    'model':names,
    'price':prices,
    'rating':ratings,
    'sim':sim,
    'processor':processor,
    'ram':ram,
    'battery':battery,
    'display':display,
    'camera':camera,
    'card':card,
    'os':os
})
df
# Out:
#                                model    price rating  \
# 0                         iQOO 13 5G  ₹47,299    NaN
# 1      Xiaomi Redmi Note 14 Pro Plus  ₹22,990    NaN
# 2                    OPPO Reno 13 5G  ₹30,990    NaN
# 3                OPPO Reno 13 Pro 5G  ₹39,999    NaN
# 4                     Tesla Pi Phone  ₹69,999    NaN
# 5                 Xiaomi Redmi A4 5G   ₹8,499     70
# 6                       Vivo Y300 5G  ₹21,999    NaN
# 7                 Realme GT 7 Pro 5G  ₹59,999    NaN
# 8                   Vivo X200 Pro 5G  ₹62,990    NaN
# 9        Xiaomi Redmi Note 13 Pro 5G  ₹17,722    NaN
# 10                   Nothing Phone 3  ₹45,990    NaN
# 11                       Vivo V40 5G  ₹32,900    NaN
# 12         OnePlus Nord CE 3 Lite 5G  ₹14,617    NaN
# 13           Motorola Edge 50 Fusion  ₹22,999    NaN
# 14          Samsung Galaxy S24 Ultra  ₹99,700    NaN
# 15                       Vivo V30 5G  ₹24,500    NaN
# 16  Xiaomi Redmi Note 13 Pro Plus 5G  ₹22,487    NaN
# 17             Samsung Galaxy A16 5G  ₹16,972    NaN
# 18              Motorola Moto G85 5G  ₹17,999    NaN
# 19       Xiaomi Redmi Note 14 Pro 5G  ₹16,990    NaN
#
#                                                   sim  \
# 0   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 1   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 2   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 3   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 4             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 5                  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 6                  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 7   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 8   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 9      Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
# 10            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 11                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 12                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 13      Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC
# 14      Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC
# 15                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 16  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 17            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 18                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 19  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
#
#                                             processor  \
# 0   Snapdragon 8 Elite, Octa Core, 4.32 GHz Processor
# 1    Snapdragon 7s Gen3, Octa Core, 2.5 GHz Processor
# 2       Dimensity 8350, Octa Core, 3.35 GHz Processor
# 3       Dimensity 8350, Octa Core, 3.35 GHz Processor
# 4                                 Octa Core Processor
# 5      Snapdragon 4s Gen2, Octa Core, 2 GHz Processor
# 6     Snapdragon 4 Gen2, Octa Core, 2.2 GHz Processor
# 7   Snapdragon 8 Elite, Octa Core, 4.32 GHz Processor
# 8       Dimensity 9400, Octa Core, 3.63 GHz Processor
# 9   Snapdragon 7s Gen 2, Octa Core, 2.4 GHz Processor
# 10     Snapdragon 8s Gen3, Octa Core, 3 GHz Processor
# 11   Snapdragon 7 Gen3, Octa Core, 2.63 GHz Processor
# 12    Snapdragon 695 5G, Octa Core, 2.2 GHz Processor
# 13   Snapdragon 7s Gen2, Octa Core, 2.4 GHz Processor
# 14    Snapdragon 8 Gen3, Octa Core, 3.3 GHz Processor
# 15   Snapdragon 7 Gen3, Octa Core, 2.63 GHz Processor
# 16  Dimensity 7200 Ultra, Octa Core, 2.8 GHz Proce...
# 17          Exynos 1330, Octa Core, 2.4 GHz Processor
# 18   Snapdragon 6s Gen3, Octa Core, 2.3 GHz Processor
# 19  Dimensity 7300 Ultra, Octa Core, 2.5 GHz Proce...
#
#                           ram                                   battery  \
# 0   12 GB RAM, 256 GB inbuilt  6000 mAh Battery with 120W Fast Charging
# 1   12 GB RAM, 256 GB inbuilt   6200 mAh Battery with 90W Fast Charging
# 2   12 GB RAM, 256 GB inbuilt   5600 mAh Battery with 80W Fast Charging
# 3   12 GB RAM, 256 GB inbuilt   5800 mAh Battery with 80W Fast Charging
# 4   16 GB RAM, 512 GB inbuilt  5000 mAh Battery with 120W Fast Charging
# 5     4 GB RAM, 64 GB inbuilt   5160 mAh Battery with 18W Fast Charging
# 6    8 GB RAM, 128 GB inbuilt   5000 mAh Battery with 80W Fast Charging
# 7   12 GB RAM, 256 GB inbuilt  5800 mAh Battery with 120W Fast Charging
# 8   12 GB RAM, 256 GB inbuilt   6000 mAh Battery with 90W Fast Charging
# 9    8 GB RAM, 128 GB inbuilt   5100 mAh Battery with 67W Fast Charging
# 10   8 GB RAM, 128 GB inbuilt  5000 mAh Battery with 100W Fast Charging
# 11   8 GB RAM, 128 GB inbuilt   5500 mAh Battery with 80W Fast Charging
# 12   8 GB RAM, 128 GB inbuilt   5000 mAh Battery with 67W Fast Charging
# 13   8 GB RAM, 128 GB inbuilt   5000 mAh Battery with 68W Fast Charging
# 14  12 GB RAM, 256 GB inbuilt   5000 mAh Battery with 45W Fast Charging
# 15   8 GB RAM, 128 GB inbuilt   5000 mAh Battery with 80W Fast Charging
# 16   8 GB RAM, 256 GB inbuilt  5000 mAh Battery with 120W Fast Charging
# 17   8 GB RAM, 128 GB inbuilt   5000 mAh Battery with 25W Fast Charging
# 18   8 GB RAM, 128 GB inbuilt   5000 mAh Battery with 33W Fast Charging
# 19   8 GB RAM, 128 GB inbuilt   5500 mAh Battery with 45W Fast Charging
#
#                                               display  \
# 0   6.82 inches, 1440 x 3168 px, 144 Hz Display wi...
# 1   6.67 inches, 1220 x 2712 px, 120 Hz Display wi...
# 2   6.59 inches, 1256 x 2760 px, 120 Hz Display wi...
# 3   6.83 inches, 1272 x 2800 px, 120 Hz Display wi...
# 4         6.73 inches, 1080 x 2448 px, 165 Hz Display
# 5   6.88 inches, 720 x 1640 px, 120 Hz Display wit...
# 6   6.67 inches, 1080 x 2400 px, 120 Hz Display wi...
# 7   6.78 inches, 1264 x 2780 px, 120 Hz Display wi...
# 8   6.78 inches, 1260 x 2800 px, 120 Hz Display wi...
# 9   6.67 inches, 1220 x 2712 px, 120 Hz Display wi...
# 10  6.67 inches, 1080 x 2400 px, 120 Hz Display wi...
# 11  6.78 inches, 1260 x 2800 px, 120 Hz Display wi...
# 12  6.72 inches, 1080 x 2400 px, 120 Hz Display wi...
# 13  6.67 inches, 1080 x 2400 px, 144 Hz Display wi...
# 14  6.8 inches, 1440 x 3120 px, 120 Hz Display wit...
# 15  6.78 inches, 1260 x 2800 px, 120 Hz Display wi...
# 16  6.67 inches, 1220 x 2712 px, 120 Hz Display wi...
# 17  6.7 inches, 1080 x 2340 px, 90 Hz Display with...
# 18  6.67 inches, 1080 x 2400 px, 120 Hz Display wi...
# 19  6.67 inches, 1220 x 2712 px, 120 Hz Display wi...
#
#                                                camera  \
# 0   50 MP + 50 MP + 50 MP Triple Rear & 32 MP Fron...
# 1   50 MP + 50 MP + 8 MP Triple Rear & 20 MP Front...
# 2         50 MP + 8 MP Dual Rear & 50 MP Front Camera
# 3   50 MP + 50 MP + 8 MP Triple Rear & 50 MP Front...
# 4   50 MP + 50 MP + 50 MP Triple Rear & 32 MP Fron...
# 5                 50 MP Dual Rear & 5 MP Front Camera
# 6         50 MP + 2 MP Dual Rear & 32 MP Front Camera
# 7   50 MP + 50 MP + 8 MP Triple Rear & 16 MP Front...
# 8   200 MP + 50 MP + 50 MP Triple Rear & 32 MP Fro...
# 9   200 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
# 10  64 MP + 50 MP + 32 MP Triple Rear & 32 MP Fron...
# 11       50 MP + 50 MP Dual Rear & 50 MP Front Camera
# 12  108 MP + 2 MP + 2 MP Triple Rear & 16 MP Front...
# 13       50 MP + 13 MP Dual Rear & 32 MP Front Camera
# 14              200 MP Quad Rear & 12 MP Front Camera
# 15       50 MP + 50 MP Dual Rear & 50 MP Front Camera
# 16  200 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
# 17  50 MP + 5 MP + 2 MP Triple Rear & 13 MP Front ...
# 18        50 MP + 8 MP Dual Rear & 32 MP Front Camera
# 19  50 MP + 8 MP + 2 MP Triple Rear & 20 MP Front ...
#
#                                  card           os
# 0                         Android v15  No FM Radio
# 1           Memory Card Not Supported  Android v14
# 2                         Android v15  No FM Radio
# 3                         Android v15  No FM Radio
# 4           Memory Card Not Supported  Android v13
# 5    Memory Card Supported, upto 1 TB  Android v14
# 6     Memory Card (Hybrid), upto 2 TB  Android v14
# 7           Memory Card Not Supported  Android v15
# 8           Memory Card Not Supported  Android v15
# 9                         Android v13  No FM Radio
# 10                        Android v14  No FM Radio
# 11          Memory Card Not Supported  Android v14
# 12    Memory Card (Hybrid), upto 1 TB  Android v13
# 13          Memory Card Not Supported  Android v14
# 14          Memory Card Not Supported  Android v14
# 15                        Android v14  No FM Radio
# 16          Memory Card Not Supported  Android v13
# 17  Memory Card (Hybrid), upto 1.5 TB  Android v14
# 18          Memory Card Not Supported  Android v14
# 19                        Android v14  No FM Radio

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   model      20 non-null     object
#  1   price      20 non-null     object
#  2   rating     1 non-null      object
#  3   sim        20 non-null     object
#  4   processor  20 non-null     object
#  5   ram        20 non-null     object
#  6   battery    20 non-null     object
#  7   display    20 non-null     object
#  8   camera     20 non-null     object
#  9   card       20 non-null     object
#  10  os         20 non-null     object
# dtypes: object(11)
# memory usage: 1.8+ KB
